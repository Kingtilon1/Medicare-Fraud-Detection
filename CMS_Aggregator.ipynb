# %% [markdown]
# ## Medicare Part D Data by Provider
#
# Aggregate by Prscrbr_NPI
#
# Keep prescriber NPI and info about name, location
#
# aggregate other data into dictionaries

# %%
import requests
import pandas as pd
from collections import defaultdict
import time

# %% [markdown]
# ### Test on 20K rows

# %%
def get_paginated_data(base_url, size=5000, max_records=1000000):
    offset = 0
    all_data = []
    
    while offset < max_records:
        res = requests.get(f"{base_url}?size={size}&offset={offset}")
        data = res.json()
        
        if not data:
            break
        
        all_data.extend(data)
        offset += size

    return pd.DataFrame(all_data)

def aggregate_by_npi(data):
    # Dictionary to aggregate data per NPI
    aggregated_data = defaultdict(lambda: defaultdict(dict))
    
    for _, row in data.iterrows():
        npi = row['Prscrbr_NPI']
        
        # Add basic prescriber info (this remains unique per NPI)
        aggregated_data[npi]['Prscrbr_Last_Org_Name'] = row['Prscrbr_Last_Org_Name']
        aggregated_data[npi]['Prscrbr_First_Name'] = row['Prscrbr_First_Name']
        aggregated_data[npi]['Prscrbr_City'] = row['Prscrbr_City']
        aggregated_data[npi]['Prscrbr_State_Abrvtn'] = row['Prscrbr_State_Abrvtn']
        aggregated_data[npi]['Prscrbr_State_FIPS'] = row['Prscrbr_State_FIPS']
        aggregated_data[npi]['Prscrbr_Type'] = row['Prscrbr_Type']
        aggregated_data[npi]['Prscrbr_Type_Src'] = row['Prscrbr_Type_Src']
        
        # Aggregate prescription-related info as dictionaries with indexed keys
        index = len(aggregated_data[npi]['Brnd_Name']) + 1  # Start at 1, increment for each new entry
        
        aggregated_data[npi]['Brnd_Name'][index] = row['Brnd_Name']
        aggregated_data[npi]['Gnrc_Name'][index] = row['Gnrc_Name']
        aggregated_data[npi]['Tot_Clms'][index] = row['Tot_Clms']
        aggregated_data[npi]['Tot_30day_Fills'][index] = row['Tot_30day_Fills']
        aggregated_data[npi]['Tot_Day_Suply'][index] = row['Tot_Day_Suply']
        aggregated_data[npi]['Tot_Drug_Cst'][index] = row['Tot_Drug_Cst']
        aggregated_data[npi]['Tot_Benes'][index] = row['Tot_Benes']
        aggregated_data[npi]['GE65_Sprsn_Flag'][index] = row['GE65_Sprsn_Flag']
        aggregated_data[npi]['GE65_Tot_Clms'][index] = row['GE65_Tot_Clms']
        aggregated_data[npi]['GE65_Tot_30day_Fills'][index] = row['GE65_Tot_30day_Fills']
        aggregated_data[npi]['GE65_Tot_Drug_Cst'][index] = row['GE65_Tot_Drug_Cst']
        aggregated_data[npi]['GE65_Tot_Day_Suply'][index] = row['GE65_Tot_Day_Suply']
        aggregated_data[npi]['GE65_Bene_Sprsn_Flag'][index] = row['GE65_Bene_Sprsn_Flag']
        aggregated_data[npi]['GE65_Tot_Benes'][index] = row['GE65_Tot_Benes']
    
    # Convert the aggregated data to a DataFrame
    aggregated_df = pd.DataFrame.from_dict(aggregated_data, orient='index')
    
    return aggregated_df

# %%
# Base URL for the dataset (Medicare Part D Providers)
base_url = "https://data.cms.gov/data-api/v1/dataset/9552739e-3d05-4c1b-8eff-ecabf391e2e5/data"

# Measure the time taken
start_time = time.time()

# Step 1: Fetch the first 20,000 rows
data = get_paginated_data(base_url, size=5000, max_records=20000)

# Step 2: Aggregate data by NPI
aggregated_data = aggregate_by_npi(data)

# Step 3: Measure the end time
end_time = time.time()

# Step 4: Display the aggregated columns (prescription-related info)
aggregated_columns = [
    'Brnd_Name', 'Gnrc_Name', 'Tot_Clms', 'Tot_30day_Fills',
    'Tot_Day_Suply', 'Tot_Drug_Cst', 'Tot_Benes', 'GE65_Sprsn_Flag',
    'GE65_Tot_Clms', 'GE65_Tot_30day_Fills', 'GE65_Tot_Drug_Cst',
    'GE65_Tot_Day_Suply', 'GE65_Bene_Sprsn_Flag', 'GE65_Tot_Benes'
]

# Show the head of aggregated columns
print(aggregated_data[aggregated_columns].head())

# Step 5: Print the total time taken
print(f"Time taken to complete: {end_time - start_time} seconds")
# Out:
#                                                     Brnd_Name  \
# 1003000126  {1: 'Amlodipine Besylate', 2: 'Atorvastatin Ca...
# 1003000142  {1: 'Acetaminophen-Codeine', 2: 'Amitriptyline...
# 1003000167             {1: 'Amoxicillin', 2: 'Dexamethasone'}
# 1003000423  {1: 'Clobetasol Propionate', 2: 'Estradiol', 3...
# 1003000480                                  {1: 'Omeprazole'}
#
#                                                     Gnrc_Name  \
# 1003000126  {1: 'Amlodipine Besylate', 2: 'Atorvastatin Ca...
# 1003000142  {1: 'Acetaminophen With Codeine', 2: 'Amitript...
# 1003000167             {1: 'Amoxicillin', 2: 'Dexamethasone'}
# 1003000423  {1: 'Clobetasol Propionate', 2: 'Estradiol', 3...
# 1003000480                                  {1: 'Omeprazole'}
#
#                                                      Tot_Clms  \
# 1003000126  {1: '19', 2: '11', 3: '15', 4: '16', 5: '12', ...
# 1003000142  {1: '17', 2: '13', 3: '33', 4: '27', 5: '45', ...
# 1003000167                                 {1: '52', 2: '13'}
# 1003000423      {1: '12', 2: '29', 3: '15', 4: '11', 5: '13'}
# 1003000480                                          {1: '12'}
#
#                                               Tot_30day_Fills  \
# 1003000126  {1: '41', 2: '29', 3: '17', 4: '26.2', 5: '18....
# 1003000142  {1: '17', 2: '13', 3: '35', 4: '27', 5: '45', ...
# 1003000167                                 {1: '52', 2: '13'}
# 1003000423    {1: '16', 2: '97.9', 3: '15', 4: '21', 5: '23'}
# 1003000480                                        {1: '18.5'}
#
#                                                 Tot_Day_Suply  \
# 1003000126  {1: '1230', 2: '870', 3: '508', 4: '783', 5: '...
# 1003000142  {1: '382', 2: '390', 3: '1050', 4: '795', 5: '...
# 1003000167                                {1: '334', 2: '14'}
# 1003000423  {1: '458', 2: '2935', 3: '450', 4: '630', 5: '...
# 1003000480                                         {1: '555'}
#
#                                                  Tot_Drug_Cst  \
# 1003000126  {1: '246.17', 2: '286.69', 3: '9503.53', 4: '2...
# 1003000142  {1: '247.6', 2: '197.65', 3: '676.81', 4: '542...
# 1003000167                          {1: '173.58', 2: '23.52'}
# 1003000423  {1: '288.74', 2: '3826.55', 3: '6843.36', 4: '...
# 1003000480                                      {1: '130.55'}
#
#                                                     Tot_Benes  \
# 1003000126  {1: '14', 2: '', 3: '', 4: '', 5: '', 6: '11',...
# 1003000142  {1: '', 2: '', 3: '21', 4: '17', 5: '28', 6: '...
# 1003000167                                 {1: '42', 2: '11'}
# 1003000423              {1: '', 2: '13', 3: '', 4: '', 5: ''}
# 1003000480                                            {1: ''}
#
#                                               GE65_Sprsn_Flag  \
# 1003000126  {1: '', 2: '', 3: '', 4: '', 5: '#', 6: '*', 7...
# 1003000142  {1: '#', 2: '*', 3: '', 4: '*', 5: '', 6: '#',...
# 1003000167                                    {1: '#', 2: ''}
# 1003000423               {1: '', 2: '', 3: '', 4: '', 5: '*'}
# 1003000480                                           {1: '*'}
#
#                                                 GE65_Tot_Clms  \
# 1003000126  {1: '19', 2: '11', 3: '15', 4: '16', 5: '', 6:...
# 1003000142  {1: '', 2: '', 3: '11', 4: '', 5: '20', 6: '',...
# 1003000167                                   {1: '', 2: '13'}
# 1003000423         {1: '12', 2: '29', 3: '0', 4: '11', 5: ''}
# 1003000480                                            {1: ''}
#
#                                          GE65_Tot_30day_Fills  \
# 1003000126  {1: '41', 2: '29', 3: '17', 4: '26.2', 5: '', ...
# 1003000142  {1: '', 2: '', 3: '11', 4: '', 5: '20', 6: '',...
# 1003000167                                   {1: '', 2: '13'}
# 1003000423       {1: '16', 2: '97.9', 3: '0', 4: '21', 5: ''}
# 1003000480                                            {1: ''}
#
#                                             GE65_Tot_Drug_Cst  \
# 1003000126  {1: '246.17', 2: '286.69', 3: '9503.53', 4: '2...
# 1003000142  {1: '', 2: '', 3: '223.66', 4: '', 5: '637.59'...
# 1003000167                                {1: '', 2: '23.52'}
# 1003000423  {1: '288.74', 2: '3826.55', 3: '0', 4: '765.15...
# 1003000480                                            {1: ''}
#
#                                            GE65_Tot_Day_Suply  \
# 1003000126  {1: '1230', 2: '870', 3: '508', 4: '783', 5: '...
# 1003000142  {1: '', 2: '', 3: '330', 4: '', 5: '257', 6: '...
# 1003000167                                   {1: '', 2: '14'}
# 1003000423     {1: '458', 2: '2935', 3: '0', 4: '630', 5: ''}
# 1003000480                                            {1: ''}
#
#                                          GE65_Bene_Sprsn_Flag  \
# 1003000126  {1: '', 2: '*', 3: '*', 4: '*', 5: '*', 6: '*'...
# 1003000142  {1: '*', 2: '*', 3: '*', 4: '*', 5: '', 6: '*'...
# 1003000167                                    {1: '#', 2: ''}
# 1003000423            {1: '*', 2: '', 3: '#', 4: '*', 5: '*'}
# 1003000480                                           {1: '*'}
#
#                                                GE65_Tot_Benes
# 1003000126  {1: '14', 2: '', 3: '', 4: '', 5: '', 6: '', 7...
# 1003000142  {1: '', 2: '', 3: '', 4: '', 5: '12', 6: '', 7...
# 1003000167                                   {1: '', 2: '11'}
# 1003000423              {1: '', 2: '13', 3: '', 4: '', 5: ''}
# 1003000480                                            {1: ''}
# Time taken to complete: 5.335084438323975 seconds

# %% [markdown]
# ### Get all Data

# %%
def get_paginated_data(base_url, size=100000):
    offset = 0
    all_data = []
    
    while True:
        res = requests.get(f"{base_url}?size={size}&offset={offset}")
        data = res.json()
        
        if not data:
            break
        
        all_data.extend(data)
        offset += size
        print(f"Fetched {offset} records...")
    
    return pd.DataFrame(all_data)

def aggregate_by_npi(data):
    # Dictionary to aggregate data per NPI
    aggregated_data = defaultdict(lambda: defaultdict(dict))
    
    for _, row in data.iterrows():
        npi = row['Prscrbr_NPI']
        
        # Add basic prescriber info (this remains unique per NPI)
        aggregated_data[npi]['Prscrbr_Last_Org_Name'] = row['Prscrbr_Last_Org_Name']
        aggregated_data[npi]['Prscrbr_First_Name'] = row['Prscrbr_First_Name']
        aggregated_data[npi]['Prscrbr_City'] = row['Prscrbr_City']
        aggregated_data[npi]['Prscrbr_State_Abrvtn'] = row['Prscrbr_State_Abrvtn']
        aggregated_data[npi]['Prscrbr_State_FIPS'] = row['Prscrbr_State_FIPS']
        aggregated_data[npi]['Prscrbr_Type'] = row['Prscrbr_Type']
        aggregated_data[npi]['Prscrbr_Type_Src'] = row['Prscrbr_Type_Src']
        
        # Aggregate prescription-related info as dictionaries with indexed keys
        index = len(aggregated_data[npi]['Brnd_Name']) + 1  # Start at 1, increment for each new entry
        
        aggregated_data[npi]['Brnd_Name'][index] = row['Brnd_Name']
        aggregated_data[npi]['Gnrc_Name'][index] = row['Gnrc_Name']
        aggregated_data[npi]['Tot_Clms'][index] = row['Tot_Clms']
        aggregated_data[npi]['Tot_30day_Fills'][index] = row['Tot_30day_Fills']
        aggregated_data[npi]['Tot_Day_Suply'][index] = row['Tot_Day_Suply']
        aggregated_data[npi]['Tot_Drug_Cst'][index] = row['Tot_Drug_Cst']
        aggregated_data[npi]['Tot_Benes'][index] = row['Tot_Benes']
        aggregated_data[npi]['GE65_Sprsn_Flag'][index] = row['GE65_Sprsn_Flag']
        aggregated_data[npi]['GE65_Tot_Clms'][index] = row['GE65_Tot_Clms']
        aggregated_data[npi]['GE65_Tot_30day_Fills'][index] = row['GE65_Tot_30day_Fills']
        aggregated_data[npi]['GE65_Tot_Drug_Cst'][index] = row['GE65_Tot_Drug_Cst']
        aggregated_data[npi]['GE65_Tot_Day_Suply'][index] = row['GE65_Tot_Day_Suply']
        aggregated_data[npi]['GE65_Bene_Sprsn_Flag'][index] = row['GE65_Bene_Sprsn_Flag']
        aggregated_data[npi]['GE65_Tot_Benes'][index] = row['GE65_Tot_Benes']
    
    # Convert the aggregated data to a DataFrame
    aggregated_df = pd.DataFrame.from_dict(aggregated_data, orient='index')
    
    return aggregated_df

# %%
# Base URL for the dataset (Medicare Part D Providers)
base_url = "https://data.cms.gov/data-api/v1/dataset/9552739e-3d05-4c1b-8eff-ecabf391e2e5/data"

# Measure the time taken
start_time = time.time()

# Step 1: Fetch all available rows
data = get_paginated_data(base_url)

# Step 2: Aggregate data by NPI
aggregated_data = aggregate_by_npi(data)

# Step 3: Measure the end time
end_time = time.time()

# Step 4: Display the aggregated columns (prescription-related info)
aggregated_columns = [
    'Brnd_Name', 'Gnrc_Name', 'Tot_Clms', 'Tot_30day_Fills',
    'Tot_Day_Suply', 'Tot_Drug_Cst', 'Tot_Benes', 'GE65_Sprsn_Flag',
    'GE65_Tot_Clms', 'GE65_Tot_30day_Fills', 'GE65_Tot_Drug_Cst',
    'GE65_Tot_Day_Suply', 'GE65_Bene_Sprsn_Flag', 'GE65_Tot_Benes'
]

# Show the head of aggregated columns
print(aggregated_data[aggregated_columns].head())

# Step 5: Print the total time taken
print(f"Time taken to complete: {end_time - start_time} seconds")
# Out:
# Fetched 5000 records...
# Fetched 10000 records...
# Fetched 15000 records...
# Fetched 20000 records...
# Fetched 25000 records...
# Fetched 30000 records...
# Fetched 35000 records...
# Fetched 40000 records...
# Fetched 45000 records...
# Fetched 50000 records...
# Fetched 55000 records...
# Fetched 60000 records...
# Fetched 65000 records...
# Fetched 70000 records...
# Fetched 75000 records...
# Fetched 80000 records...
# Fetched 85000 records...
# Fetched 90000 records...
# Fetched 95000 records...
# Fetched 100000 records...
# Fetched 105000 records...
# Fetched 110000 records...
# Fetched 115000 records...
# Fetched 120000 records...
# Fetched 125000 records...
# Fetched 130000 records...
# Fetched 135000 records...
# Fetched 140000 records...
# Fetched 145000 records...
# Fetched 150000 records...
# Fetched 155000 records...
# Fetched 160000 records...
# Fetched 165000 records...
# Fetched 170000 records...
# Fetched 175000 records...
# Fetched 180000 records...
# Fetched 185000 records...
# Fetched 190000 records...
# Fetched 195000 records...
# Fetched 200000 records...
# Fetched 205000 records...
# Fetched 210000 records...
# Fetched 215000 records...
# Fetched 220000 records...
# Fetched 225000 records...
# Fetched 230000 records...
# Fetched 235000 records...
# Fetched 240000 records...
# Fetched 245000 records...
# Fetched 250000 records...
# Fetched 255000 records...
# Fetched 260000 records...
# Fetched 265000 records...
# Fetched 270000 records...
# Fetched 275000 records...
# Fetched 280000 records...
# Fetched 285000 records...
# Fetched 290000 records...
# Fetched 295000 records...
# Fetched 300000 records...
# Fetched 305000 records...
# Fetched 310000 records...
# Fetched 315000 records...
# Fetched 320000 records...
# Fetched 325000 records...
# Fetched 330000 records...
# Fetched 335000 records...
# Fetched 340000 records...
# Fetched 345000 records...
# Fetched 350000 records...
# Fetched 355000 records...
# Fetched 360000 records...
# Fetched 365000 records...
# Fetched 370000 records...
# Fetched 375000 records...
# Fetched 380000 records...
# Fetched 385000 records...
# Fetched 390000 records...
# Fetched 395000 records...
# Fetched 400000 records...
# Fetched 405000 records...
# Fetched 410000 records...
# Fetched 415000 records...
# Fetched 420000 records...
# Fetched 425000 records...
# Fetched 430000 records...
# Fetched 435000 records...
# Fetched 440000 records...
# Fetched 445000 records...
# Fetched 450000 records...
# Fetched 455000 records...
# Fetched 460000 records...
# Fetched 465000 records...
# Fetched 470000 records...
# Fetched 475000 records...
# Fetched 480000 records...
# Fetched 485000 records...
# Fetched 490000 records...
# Fetched 495000 records...
# Fetched 500000 records...
# Fetched 505000 records...
# Fetched 510000 records...
# Fetched 515000 records...
# Fetched 520000 records...
# Fetched 525000 records...
# Fetched 530000 records...
# Fetched 535000 records...
# Fetched 540000 records...
# Fetched 545000 records...
# Fetched 550000 records...
# Fetched 555000 records...
# Fetched 560000 records...
# Fetched 565000 records...
# Fetched 570000 records...
# Fetched 575000 records...
# Fetched 580000 records...
# Fetched 585000 records...
# Fetched 590000 records...
# Fetched 595000 records...
# Fetched 600000 records...
# Fetched 605000 records...
# Fetched 610000 records...
# Fetched 615000 records...
# Fetched 620000 records...
# Fetched 625000 records...
# Fetched 630000 records...
# Fetched 635000 records...
# Fetched 640000 records...
# Fetched 645000 records...
# Fetched 650000 records...
# Fetched 655000 records...
# Fetched 660000 records...
# Fetched 665000 records...
# Fetched 670000 records...
# Fetched 675000 records...
# Fetched 680000 records...
# Fetched 685000 records...
# Fetched 690000 records...
# Fetched 695000 records...
# Fetched 700000 records...
# Fetched 705000 records...
# Fetched 710000 records...
# Fetched 715000 records...
# Fetched 720000 records...
# Fetched 725000 records...
# Fetched 730000 records...
# Fetched 735000 records...
# Fetched 740000 records...
# Fetched 745000 records...
# Fetched 750000 records...
# Fetched 755000 records...
# Fetched 760000 records...
# Fetched 765000 records...
# Fetched 770000 records...
# Fetched 775000 records...
# Fetched 780000 records...
# Fetched 785000 records...
# Fetched 790000 records...
# Fetched 795000 records...
# Fetched 800000 records...
# Fetched 805000 records...
# Fetched 810000 records...
# Fetched 815000 records...
# Fetched 820000 records...
# Fetched 825000 records...
# Fetched 830000 records...
# Fetched 835000 records...
# Fetched 840000 records...
# Fetched 845000 records...
# Fetched 850000 records...
# Fetched 855000 records...
# Fetched 860000 records...
# Fetched 865000 records...
# Fetched 870000 records...
# Fetched 875000 records...
# Fetched 880000 records...
# Fetched 885000 records...
# Fetched 890000 records...
# Fetched 895000 records...
# Fetched 900000 records...
# Fetched 905000 records...
# Fetched 910000 records...
# Fetched 915000 records...
# Fetched 920000 records...
# Fetched 925000 records...
# Fetched 930000 records...
# Fetched 935000 records...
# Fetched 940000 records...
# Fetched 945000 records...
# Fetched 950000 records...
# Fetched 955000 records...
# Fetched 960000 records...
# Fetched 965000 records...
# Fetched 970000 records...
# Fetched 975000 records...
# Fetched 980000 records...
# Fetched 985000 records...
# Fetched 990000 records...
# Fetched 995000 records...
# Fetched 1000000 records...
# Fetched 1005000 records...
# Fetched 1010000 records...
# Fetched 1015000 records...
# Fetched 1020000 records...
# Fetched 1025000 records...
# Fetched 1030000 records...
# Fetched 1035000 records...
# Fetched 1040000 records...
# Fetched 1045000 records...
# Fetched 1050000 records...
# Fetched 1055000 records...
# Fetched 1060000 records...
# Fetched 1065000 records...
# Fetched 1070000 records...
# Fetched 1075000 records...
# Fetched 1080000 records...
# Fetched 1085000 records...
# Fetched 1090000 records...
# Fetched 1095000 records...
# Fetched 1100000 records...
# Fetched 1105000 records...
# Fetched 1110000 records...
# Fetched 1115000 records...
# Fetched 1120000 records...
# Fetched 1125000 records...
# Fetched 1130000 records...
# Fetched 1135000 records...
# Fetched 1140000 records...
# Fetched 1145000 records...
# Fetched 1150000 records...
# Fetched 1155000 records...
# Fetched 1160000 records...
# Fetched 1165000 records...
# Fetched 1170000 records...
# Fetched 1175000 records...
# Fetched 1180000 records...
# Fetched 1185000 records...
# Fetched 1190000 records...
# Fetched 1195000 records...
# Fetched 1200000 records...
# Fetched 1205000 records...
# Fetched 1210000 records...
# Fetched 1215000 records...
# Fetched 1220000 records...
# Fetched 1225000 records...
# Fetched 1230000 records...
# Fetched 1235000 records...
# Fetched 1240000 records...
# Fetched 1245000 records...
# Fetched 1250000 records...
# Fetched 1255000 records...
# Fetched 1260000 records...
# Fetched 1265000 records...
# Fetched 1270000 records...
# Fetched 1275000 records...
# Fetched 1280000 records...
# Fetched 1285000 records...
# Fetched 1290000 records...
# Fetched 1295000 records...
# Fetched 1300000 records...
# Fetched 1305000 records...
# Fetched 1310000 records...
# Fetched 1315000 records...
# Fetched 1320000 records...
# Fetched 1325000 records...
# Fetched 1330000 records...
# Fetched 1335000 records...
# Fetched 1340000 records...
# Fetched 1345000 records...
# Fetched 1350000 records...
# Fetched 1355000 records...
# Fetched 1360000 records...
# Fetched 1365000 records...
# Fetched 1370000 records...
# Fetched 1375000 records...
# Fetched 1380000 records...
# Fetched 1385000 records...
# Fetched 1390000 records...
# Fetched 1395000 records...
# Fetched 1400000 records...
# Fetched 1405000 records...
# Fetched 1410000 records...
# Fetched 1415000 records...
# Fetched 1420000 records...
# Fetched 1425000 records...
# Fetched 1430000 records...
# Fetched 1435000 records...
# Fetched 1440000 records...
# Fetched 1445000 records...
# Fetched 1450000 records...
# Fetched 1455000 records...
# Fetched 1460000 records...
# Fetched 1465000 records...
# Fetched 1470000 records...
# Fetched 1475000 records...
# Fetched 1480000 records...
# Fetched 1485000 records...
# Fetched 1490000 records...
# Fetched 1495000 records...
# Fetched 1500000 records...
# Fetched 1505000 records...
# Fetched 1510000 records...
# Fetched 1515000 records...
# Fetched 1520000 records...
# Fetched 1525000 records...
# Fetched 1530000 records...
# Fetched 1535000 records...
# Fetched 1540000 records...
# Fetched 1545000 records...
# Fetched 1550000 records...
# Fetched 1555000 records...
# Fetched 1560000 records...
# Fetched 1565000 records...
# Fetched 1570000 records...
# Fetched 1575000 records...
# Fetched 1580000 records...
# Fetched 1585000 records...
# Fetched 1590000 records...
# Fetched 1595000 records...
# Fetched 1600000 records...
# Fetched 1605000 records...
# Fetched 1610000 records...
# Fetched 1615000 records...
# Fetched 1620000 records...
# Fetched 1625000 records...
# Fetched 1630000 records...
# Fetched 1635000 records...
# Fetched 1640000 records...
# Fetched 1645000 records...
# Fetched 1650000 records...
# Fetched 1655000 records...
# Fetched 1660000 records...
# Fetched 1665000 records...
# Fetched 1670000 records...
# Fetched 1675000 records...
# Fetched 1680000 records...
# Fetched 1685000 records...
# Fetched 1690000 records...
# Fetched 1695000 records...
# Fetched 1700000 records...
# Fetched 1705000 records...
# Fetched 1710000 records...
# Fetched 1715000 records...
# Fetched 1720000 records...
# Fetched 1725000 records...
# Fetched 1730000 records...
# Fetched 1735000 records...
# Fetched 1740000 records...
# Fetched 1745000 records...
# Fetched 1750000 records...
# Fetched 1755000 records...
# Fetched 1760000 records...
# Fetched 1765000 records...
# Fetched 1770000 records...
# Fetched 1775000 records...
# Fetched 1780000 records...
# Fetched 1785000 records...
# Fetched 1790000 records...
# Fetched 1795000 records...
# Fetched 1800000 records...
# Fetched 1805000 records...
# Fetched 1810000 records...
# Fetched 1815000 records...
# Fetched 1820000 records...
# Fetched 1825000 records...
# Fetched 1830000 records...
# Fetched 1835000 records...
# Fetched 1840000 records...
# Fetched 1845000 records...
# Fetched 1850000 records...
# Fetched 1855000 records...
# Fetched 1860000 records...
# Fetched 1865000 records...
# Fetched 1870000 records...
# Fetched 1875000 records...
# Fetched 1880000 records...
# Fetched 1885000 records...
# Fetched 1890000 records...
# Fetched 1895000 records...
# Fetched 1900000 records...
# Fetched 1905000 records...
# Fetched 1910000 records...
# Fetched 1915000 records...
# Fetched 1920000 records...
# Fetched 1925000 records...
# Fetched 1930000 records...
# Fetched 1935000 records...
# Fetched 1940000 records...
# Fetched 1945000 records...
# Fetched 1950000 records...
# Fetched 1955000 records...
# Fetched 1960000 records...
# Fetched 1965000 records...
# Fetched 1970000 records...
# Fetched 1975000 records...
# Fetched 1980000 records...
# Fetched 1985000 records...
# Fetched 1990000 records...
# Fetched 1995000 records...
# Fetched 2000000 records...
# Fetched 2005000 records...
# Fetched 2010000 records...
# Fetched 2015000 records...
# Fetched 2020000 records...
# Fetched 2025000 records...
# Fetched 2030000 records...
# Fetched 2035000 records...
# Fetched 2040000 records...
# Fetched 2045000 records...
# Fetched 2050000 records...
# Fetched 2055000 records...
# Fetched 2060000 records...
# Fetched 2065000 records...
# Fetched 2070000 records...
# Fetched 2075000 records...
# Fetched 2080000 records...
# Fetched 2085000 records...
# Fetched 2090000 records...
# Fetched 2095000 records...
# Fetched 2100000 records...
# Fetched 2105000 records...
# Fetched 2110000 records...
# Fetched 2115000 records...
# Fetched 2120000 records...
# Fetched 2125000 records...
# Fetched 2130000 records...
# Fetched 2135000 records...
# Fetched 2140000 records...
# Fetched 2145000 records...
# Fetched 2150000 records...
# Fetched 2155000 records...
# Fetched 2160000 records...
# Fetched 2165000 records...
# Fetched 2170000 records...
# Fetched 2175000 records...
# Fetched 2180000 records...
# Fetched 2185000 records...
# Fetched 2190000 records...
# Fetched 2195000 records...
# Fetched 2200000 records...
# Fetched 2205000 records...
# Fetched 2210000 records...
# Fetched 2215000 records...
# Fetched 2220000 records...
# Fetched 2225000 records...
# Fetched 2230000 records...
# Fetched 2235000 records...
# Fetched 2240000 records...
# Fetched 2245000 records...
# Fetched 2250000 records...
# Fetched 2255000 records...
# Fetched 2260000 records...
# Fetched 2265000 records...
# Fetched 2270000 records...
# Fetched 2275000 records...
# Fetched 2280000 records...
# Fetched 2285000 records...
# Fetched 2290000 records...
# Fetched 2295000 records...
# Fetched 2300000 records...
# Fetched 2305000 records...
# Fetched 2310000 records...
# Fetched 2315000 records...
# Fetched 2320000 records...
# Fetched 2325000 records...
# Fetched 2330000 records...
# Fetched 2335000 records...
# Fetched 2340000 records...
# Fetched 2345000 records...
# Fetched 2350000 records...
# Fetched 2355000 records...
# Fetched 2360000 records...
# Fetched 2365000 records...
# Fetched 2370000 records...
# Fetched 2375000 records...
# Fetched 2380000 records...
# Fetched 2385000 records...
# Fetched 2390000 records...
# Fetched 2395000 records...
# Fetched 2400000 records...
# Fetched 2405000 records...
# Fetched 2410000 records...
# Fetched 2415000 records...
# Fetched 2420000 records...
# Fetched 2425000 records...
# Fetched 2430000 records...
# Fetched 2435000 records...
# Fetched 2440000 records...
# Fetched 2445000 records...
# Fetched 2450000 records...
# Fetched 2455000 records...
# Fetched 2460000 records...
# Fetched 2465000 records...
# Fetched 2470000 records...
# Fetched 2475000 records...
# Fetched 2480000 records...
# Fetched 2485000 records...
# Fetched 2490000 records...
# Fetched 2495000 records...
# Fetched 2500000 records...
# Fetched 2505000 records...
# Fetched 2510000 records...
# Fetched 2515000 records...
# Fetched 2520000 records...
# Fetched 2525000 records...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 8
#       5 start_time = time.time()
#       7 # Step 1: Fetch all available rows
# ----> 8 data = get_paginated_data(base_url)
#      10 # Step 2: Aggregate data by NPI
#      11 aggregated_data = aggregate_by_npi(data)
#
# Cell In[13], line 6, in get_paginated_data(base_url, size)
#       3 all_data = []
#       5 while True:
# ----> 6     res = requests.get(f"{base_url}?size={size}&offset={offset}")
#       7     data = res.json()
#       9     if not data:
#
# File c:\Users\bleac\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\bleac\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\bleac\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\bleac\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\bleac\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\bleac\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\bleac\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\bleac\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\bleac\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File c:\Users\bleac\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\bleac\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\bleac\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\bleac\anaconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\bleac\anaconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(len(aggregated_data))
# Out:
# 918
